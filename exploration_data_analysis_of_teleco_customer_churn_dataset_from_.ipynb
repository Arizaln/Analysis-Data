# %% [markdown]
# # soal :
#
# # Missing Values Checking
# # Categorical Data Encoding
# # Anomalies and Outlier Handling

# %% [markdown]
# # persiapan untuk mengerjakan soal

# %%
# untuk memuat, manipulasi data
import pandas as pd
pd.set_option('display.max_columns', None) #untuk menampilkan semua data agar terlihat


# untuk memvisualisasikan data 
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
# melihat tipe data 
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# sort TotalCharges karena tipe datanya object tapi datanya float
data_sort = data.sort_values(by='TotalCharges')
data_sort
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# ...          ...     ...            ...     ...        ...     ...
# 6646  8249-THVEC    Male              0     Yes        Yes      51
# 5598  6051-PTVNS  Female              0     Yes        Yes      55
# 3686  5899-MQZZL  Female              0      No         No      13
# 3353  4536-PLEQY    Male              0     Yes         No      12
# 2845  9093-FPDLG  Female              0      No         No      11
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 936           Yes            No             DSL                  Yes
# ...

# %% [markdown]
# ternyata setelah melihat kolom total charges alasan kolom tersebut tipe datanya object adalah karena terdapat baris kosong (bukan NaN) pada kolom tersebut. jadi python memukul rata menjadi object. maka kita harus merubah baris kosong tersebut menjadi NaN dan merubah tipe datanya menjadi float64

# %%
# merubah kolom TotalCharges
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce') #merubah tipe pada totalcharges menjadi float64,Dengan mrnggunakan errors='coerce', akan mengubah nilai non-numerik menjadi NaN.

# %%
# merubah value kolom seniorcitizen agar lebih mudah untuk memetakan
data["SeniorCitizen"] = data["SeniorCitizen"].map({1:'Yes', 0:'No'})

# %%
data_sort2 = data.sort_values(by='TotalCharges')
data_sort2
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 1654  2967-MXRAV    Male            No     Yes        Yes       1
# 6489  9318-NKNFC    Male            No      No         No       1
# 1151  8992-CEUEN  Female            No      No         No       1
# 4939  9975-SKRNR    Male            No      No         No       1
# 583   1423-BMPBQ  Female            No     Yes        Yes       1
# ...          ...     ...           ...     ...        ...     ...
# 3826  3213-VVOLG    Male            No     Yes        Yes       0
# 4380  2520-SGTTA  Female            No     Yes        Yes       0
# 5218  2923-ARZLG    Male            No     Yes        Yes       0
# 6670  4075-WKNIU  Female            No     Yes        Yes       0
# 6754  2775-SEFEE    Male            No      No        Yes       0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 1654          Yes            No              No  No internet service
# ...

# %%
# cek tipe data TotalCharges
data['TotalCharges'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# setelah merubah kolom TotalCharges saatnya kita cek missing values

# %%
# cek missing values
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# # missing values handle

# %%
# mengisi nilai NaN dengan 0
data.fillna(value=0, inplace=True)

# %%
# sort nilai pada TotalCharge sudah benar
data_sort3=data.sort_values(by='TotalCharges')
data_sort3
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 3826  3213-VVOLG    Male            No     Yes        Yes       0
# 5218  2923-ARZLG    Male            No     Yes        Yes       0
# 4380  2520-SGTTA  Female            No     Yes        Yes       0
# 753   3115-CZMZD    Male            No      No        Yes       0
# 488   4472-LVYGI  Female            No     Yes        Yes       0
# ...          ...     ...           ...     ...        ...     ...
# 2187  8879-XUAHX    Male            No     Yes         No      71
# 5347  9788-HNGUT    Male            No     Yes         No      72
# 6768  9739-JLPQJ  Female            No     Yes        Yes      72
# 4586  7569-NMZYQ  Female            No     Yes        Yes      72
# 4610  2889-FPWRM    Male            No     Yes         No      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 3826          Yes               Yes              No  No internet service
# ...

# %%
# cek missing value sudah benar
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Categorical Data Encoding

# %%
# menghapus kolom customerID karena tidak terpakai ketika akan diencoding
data.drop('customerID',axis=1,inplace=True)

# %%
# get_dummies() digunakan untuk mengubah variabel kategori menjadi variabel dummy/indikator.
data_dummy = pd.get_dummies(data)
data_dummy
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0          1           29.85         29.85              1            0
# 1         34           56.95       1889.50              0            1
# 2          2           53.85        108.15              0            1
# 3         45           42.30       1840.75              0            1
# 4          2           70.70        151.65              1            0
# ...      ...             ...           ...            ...          ...
# 7038      24           84.80       1990.50              0            1
# 7039      72          103.20       7362.90              1            0
# 7040      11           29.60        346.45              1            0
# 7041       4           74.40        306.60              0            1
# 7042      66          105.65       6844.50              0            1
#
#       SeniorCitizen_No  SeniorCitizen_Yes  Partner_No  Partner_Yes  \
# ...

# %% [markdown]
# # Anomalies and Outlier Handling

# %%
data.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2279.734304
# std      24.559481       30.090047   2266.794470
# min       0.000000       18.250000      0.000000
# 25%       9.000000       35.500000    398.550000
# 50%      29.000000       70.350000   1394.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# kolom tenur

# %%
# rumus outliers
Q1=data['tenure'].quantile(0.25)
Q3=data['tenure'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)

# %%
# outlier_atas
outliers = data[data['tenure']>upper_bound]
# outlier_bawah
# outliers = data[data['tenure']<lower_bound]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %%
# mencari outliers menggunakan mathplot dan seaborn
plt.figure() # untuk membuat figure baru
sns.boxplot(x=data['tenure'])
plt.show()

# %% [markdown]
# kolom MonthlyCharges

# %%
# rumus outliers
Q1=data['MonthlyCharges'].quantile(0.25)
Q3=data['MonthlyCharges'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)

# %%
# outlier_atas
outliers = data[data['MonthlyCharges']>upper_bound]
# outlier_bawah
# outliers = data[data['MonthlyCharges']<lower_bound]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %%
# mencari outliers menggunakan mathplot dan seaborn
plt.figure() # untuk membuat figure baru
sns.boxplot(x=data['MonthlyCharges'])
plt.show()

# %% [markdown]
# kolom TotalCharges

# %%
# rumus outliers
Q1=data['TotalCharges'].quantile(0.25)
Q3=data['TotalCharges'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)

# %%
# outlier_atas
outliers = data[data['TotalCharges']>upper_bound]
# outlier_bawah
# outliers = data[data['TotalCharges']<lower_bound]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %%
# # mencari outliers menggunakan mathplot dan seaborn
plt.figure() # untuk membuat figure baru
sns.boxplot(x=data['TotalCharges'])
plt.show()

# %% [markdown]
# kesimpulanya adalah tidak ada outlier pada 3 kolom tersebut, dan untuk anomalinya sendiripun tidak ada, dataset ini bersih dan bagus.
